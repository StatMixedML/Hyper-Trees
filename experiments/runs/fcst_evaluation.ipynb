# %% [markdown]
# # Imports

# %%
from experiments.utils import evaluate_forecasts

# %% [markdown]
# # Load Forecasts and Evaluate
#
# Here you can choose which type of forecasts to evaluate by changing the `train_type` argument:
#
# - to evalualte local forecasts, use `train_type="local"`
# - to evaluate global forecasts, use `train_type="global"`

# %%
evaluate_forecasts(results_dir="results/", train_type="global")
